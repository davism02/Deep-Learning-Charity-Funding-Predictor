# %% [markdown]
# <a href="https://colab.research.google.com/github/davism02/Deep-Learning-Charity-Funding-Predictor/blob/main/Optimization1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
url = 'https://raw.githubusercontent.com/davism02/Deep-Learning-Charity-Funding-Predictor/main/Resources/charity_data.csv'

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv(url)
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df = application_df.drop(columns = ['EIN'])

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at NAME value counts for binning
counts0 = application_df['NAME'].value_counts()
counts0
# Out:
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC     408
#                                                    ...
# NATIONAL ALLIANCE OF PRISONERS & PAROLEES             1
# COLONIAL PLACE APARTMENTS INC                         1
# GLACIER PARK ELEMENTARY PTSA 9 14 5                   1
# MELS BGC CORP                                         1
# RENTON ECUMENICAL ASSOCIATION OF CHURCHES             1
# Name: NAME, Length: 19568, dtype: int64

# %%
# Choose a cutoff value and create a list of NAME to be replaced
# use the variable name `Name_to_replace`
#  YOUR CODE GOES HERE

Names_to_replace = list(counts0[counts0<5].index)
Names_to_replace
# Out:
# ['WOODMEN OF THE WORLD LIFE INSURANCE SOCIETY',
#  'SAFARI CLUB INTERNATIONAL FOUNDATION',
#  'ALASKA PTA',
#  'THE UNITED STATE PONY CLUBS INC',
#  'TENNESSEE MUSIC EDUCATION ASSOCIATION',
#  'AMERICAN ORFF-SCHULWERK ASSOCIATION',
#  'SWEDISH WOMENS EDUCATIONAL ASSOCIATION',
#  '4-H CLUBS & AFFILIATED 4-H ORGANIZATIONS',
#  'EPSILON PI TAU INC',
#  'PUGET SOUND UNISERV COUNCIL',
#  'UNITED MINE WORKERS OF AMERICA- INTERNATIONAL',
#  'BLUE STAR MOTHERS OF AMERICA INC',
#  'PI KAPPA ALPHA FRATERNITY',
#  'PARENTS FAMILIES AND FRIENDS OF LESBIANS AND GAYS INC',
#  'INTERNATIONAL ASSOCIATION OF EATING DISORDERS PROFESSIONALS FOUNDATI',
#  'COMMEMORATIVE AIR FORCE',
#  'LOUISIANA 4-H FOUNDTION',
#  'DELTA CHI NATIONAL HOUSING CORPORATION',
#  'LIFE STEPS FOUNDATION INC',
#  'GAMMA PHI BETA SORORITY INC',
#  'TEXAS WATER UTILITIES ASSOCIATION',
#  'ANCIENT FREE AND ACCEPTED MASONS OF OKLAHOMA',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF KANSAS',
#  'UTILITY WORKERS UNION OF AMERICA AFL-CIO',
#  'DEPARTMENT OF OREGON LADIES AUXILIARY TO THE VFW OF THE US',
#  'PILOT CLUB INTERNATIONAL',
#  'BAKERY CONFECTIONERY TOBACCO WORKERS AND GRAIN MILLERS INTL UNI',
#  'ORDER OF THE EASTERN STAR OF MISSOURI GRAND CHAPTER',
#  'DEPARTMENT OF OKLAHOMA LADIES AUXILIARY TO THE VFW INC',
#  'COMMUNICATION ALLIANCE TO NETWORK THOROUGHBRED EX-RACEHORSES',
#  'NATIONAL ASSOCIATION OF NEGRO BUSINESS AND PROFESSIONAL WOMENS C',
#  'STANDUP PARENTING INC',
#  'JEFFERSON CITY SENIOR HIGH SCHOOL PARENT TEACHERS ORGANIZATION',
#  'NATIONAL SOCIETY OF THE CHILDREN OF THE AMERICAN REVOLUTION',
#  'INTERNATIONAL READING ASSOCIATION INC',
#  'TEXAS EXTENSION EDUCATION ASSOCIATION',
#  'MUSIC TEACHERS NATIONAL ASSOCIATION',
#  'AMERICAN COACH ASSOCIATION',
#  'JUNIOR ROLLER DERBY ASSOCIATION',
#  'COMPUTER USING EDUCATORS',
#  'AMERICAN SOCIETY OF HEATING REFRIGERATING & A-C ENGINEERS',
#  'AMATEUR ATHLETIC UNIONS OF THE US',
#  'SOROPTIMIST INTERNATIONAL TO THE AMERICAS INC',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF OREGON',
#  'YOUNG CATHOLIC PROFESSIONALS',
#  'AMATEUR ATHLETIC UNION OV THE UNITED STATES INC',
#  'OMEGA PSI PHI FRATERNITY',
#  'PTA IDAHO CONGRESS',
#  'INDUSTRIAL WORKERS OF THE WORLD',
#  'KNIGHTS OF PETER CLAVER',
#  'VESTAVIA HILLS PARENT TEACHER ORGANIZATION INC',
#  'FREE & ACCEPTED MASONS OF LOUISIANA GRAND LODGE',
#  'AMALGAMATED TRANSIT UNION',
#  'INSTITUTE OF ELECTRICAL AND ELECTRONICS ENGINEERS',
#  'NATIONAL HOOK-UP OF BLACK WOMEN',
#  'METHODIST RETIREMENT COMMUNITIES',
#  'INTERNATIONAL ASSOCIATION OF ASSESSING OFFICERS',
#  'BACK COUNTRY HORSEMEN OF AMERICA',
#  'TEXAS STATE BRANCH 948 NATIONAL ASSOCIATION OF POSTAL SUPERVISORS',
#  'PTA NEW MEXICO CONGRESS',
#  'PHI DELTA KAPP INTERNATIONAL INC',
#  'WESTERN GOVERNORS UNIVERSITY',
#  'SIGMA GAMMA RHO SORORITY INC',
#  'AMERICAN ROSE SOCIETY',
#  'SUNRISE 2000 INC',
#  'IDAHO CHAPLAINS CORPS INC',
#  'NATIONAL SORORITY OF PHI DELTA KAPPA INC',
#  'INTELLIGENT TRANSPORTATION SOCIETY OF AMERICA ITS AMERICA',
#  'EXPERIMENTAL AIRCRAFT ASSOCIATION',
#  'TXCPSO INC',
#  'KIDS ENJOY EXERCISE NOW',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF LOUISIANA',
#  'NATIONAL BLACK NURSES ASSOCIATION INC',
#  'PACIFIC COAST NORWEGIAN SINGERS ASSOCIATION',
#  'SUPREME TEMPLE PYTHIAN SISTERS',
#  'ASSOCIATION OF SEWING AND DESIGN PROFESSIONALS INC',
#  'CALIFORNIA ASSOCIATION FOR NURSE PRACTITIONERS',
#  'DERMATOLOGY NURSES ASSOCIATION',
#  'SMOCKING ARTS GUILD OF AMERICA INC',
#  'PTA TENNESSEE CONGRESS OF PARENTS TEACHERS INC',
#  'TEXAS SOCIETY OF PROFESSIONAL ENGINEERS',
#  'ALPHA KAPPA PSI FRATERNITY',
#  'ASSOCIATION OF PROPASAL MANAGEMENT PROFESSIONALS',
#  'ASET-THE NEURODIAGNOSTIC SOCIETY',
#  'AMERCIAN LEGION',
#  'FUTURE FARMERS OF AMERICA',
#  'PTA WASHINGTON CONGRESS',
#  'ENTREPRENEURS ORGANIZATION',
#  'LAMBDA ALPHA INTERNATIONAL',
#  'COLORADO COALITION FOR THE HOMELESS',
#  'NATIONAL SOCIETY OF BLACK ENGINEERS',
#  'GYRO INTERNATIONAL',
#  'VERITY HEALTH SYSTEM OF CALIFORNIA INC',
#  'AMERICAN ASSOCIATION OF ZOO KEEPERS',
#  'FEDERATION OF TEXAS A&M UNIVERSITY MOTHERS CLUB',
#  'SERTOMA INTERNATIONAL SPONSORSHIP FUND',
#  'REAL ESTATE STAGING ASSOCIATION INC',
#  'NATIONAL HUMAN RESOURCES ASSOCIATION INC',
#  'INTERNATIONAL UNION OF PAINTERS AND ALLIED TRADES',
#  'ANCIENT FREE & ACCEPTED MASONS OF OREGON',
#  'UNIVERSITY OF FLORIDA NATIONAL ALUMNI ASSOCIATION INC',
#  'INSTITUTE OF REAL ESTATE MANAGEMENT OF THE NATL ASSN OF REALTORS',
#  'AMERICAN FISHERIES SOCIETY',
#  'NATIONAL FELLOWSHIP OF RACEWAY MINISTRIES',
#  'WASHINTON STATE UNIVERSITY',
#  'WASHINGTON STATE UNIVERSITY 4-H CLUBS AND AFFILIATED 4-H ORGANIZAT',
#  'FLORIDA NATIVE PLANT SOCIETY INC',
#  'NATIONAL SPEAKERS ASSOCIATION',
#  'NORTH AMERICAN BUTTERFLY ASSOCIATION INC',
#  'HILLEL THE FOUNDATION FOR JEWISH CAMPUS LIFE',
#  'INTERNATIONAL SOCIETY OF AUTOMATION',
#  'HAMPTON UNIVERSITY',
#  'CALIFORNIA PODIATRIC MEDICAL ASSOC',
#  'PHI SIGMA KAPPA',
#  'FEDERALLY EMPLOYED WOMEN INC',
#  'DAUGHTERS OF ISIS OF NORTH & SOUTH AMERICA',
#  'AMERICAN MARKETING ASSOCIATION INC',
#  'ORDER OF THE FOUNDERS & PATRIOTS OF AMERICA',
#  'VFW AUXILIARY DEPARTMENT OF MISSOURI',
#  'FLORIDA EDUCATION ASSOCIATION',
#  'ROYAL ARCH MASONS OF KANSAS',
#  'CALIFORNIA PILOTS ASSOCIATION',
#  'THE ARK OF TEXAS',
#  'AMERICAN GROUP PSYCHOTHERAPY ASSOCIATION INC',
#  'ROYAL ARCH MASONS OF CALIFORNIA',
#  'OREGON HIGH SCHOOL RODEO ASSOCIATION INC',
#  'SOUTHERN EARLY CHILDHOOD ASSOC',
#  'ALLIANCE FOR RETIRED AMERICANS',
#  'THETA XI FRATERNITY',
#  'APPA ASSOCIATION OF HIGHER EDUCATION FACILITIES OFFICERS',
#  'NORTHWEST SWIM CIRCUIT',
#  'PHI DELTA KAPPA INTERNATIONAL INC',
#  'TRUSTEES OF DARTMOUTH COLLEGE',
#  'CLIPPED WINGS UNITED AIR LINES STEWARDESS ALUMNAE & FLIGHT ATTEND',
#  'NORTH AMERICAN FOLK MUSIC AND DANCE ALLIANCE INC',
#  'HEALTH OCCUPATIONS STUDENTS OF AMERICA',
#  'UNITED STATES BOWLING CONGRESS',
#  'LIGHT FOR LIFE FOUNDATION INTERNATIONAL',
#  'CENTER FOR THE STUDY OF CLASSICAL ARCHITECTURE INC',
#  'UNITED BROTHERHOOD OF CARPENTERS & JOINERS OF AMERICA',
#  'LAMBDA CHI ALPHA FRATERNITY INC',
#  'BETA BETA BETA NATIONAL BIOLOGICAL HONOR SOCIETY',
#  'SOIL AND WATER CONSERVATION SOCIETY',
#  'SOCIETY FOR MAINTENANCE AND RELIABILITY PROFESSIONALS FND',
#  'CORENET GLOBAL INC',
#  'NATIONAL ENGINEERS WEEK FOUNDATION',
#  'PARAGON CHRISTIAN ALLIANCE INTERNATIONAL INC',
#  'UEMPOWERU INC',
#  'TRAUMA INTERVENTION PROGRAMS INC',
#  'OHIO STATE UNIVERSITY ALUMNI ASSOCIATION INC',
#  'WESTERN DRESSAGE ASSOCIATION OF AMERICA',
#  'CFIRE CHRISTIAN FUNDAMENTALIST INTERNAL REVENUE EMPLOYEES',
#  'ACADEMY OF MANAGED CARE PHARMACY',
#  'ORDER OF EASTERN STAR OF OKLAHOMA',
#  'ACADEMY OF GENERAL DENTISTRY',
#  'ORDER OF EASTERN STAR PRINCE HALL AFFILIATION OF LOUISIANA',
#  'PTA KANSAS CONGRESS OF PARENTS AND TEACHERS',
#  'GRAMBLING UNIVERSITY NATIONAL ALUMNI ASSOCIATION',
#  'ILLUMAN',
#  'ANCIENT ORDER OF HIBERNIANS IN AMERICA',
#  'GREYHOUND PETS OF AMERICA',
#  'ALLIANCE OF DIVINE LOVE INC',
#  'SAFARI CLUB INTERNATIONAL',
#  'GIRLS ON THE RUN INTERNATIONAL',
#  'UNITED FOOD AND COMMERCIAL WORKERS INTERNATIONAL UNION',
#  'PTA ARIZONA CONGRESS OF PARENTS AND TEACHERS INC',
#  'JOSHUA INC',
#  'FREE & ACCEPTED MASONS OF ALABAMA',
#  'AMERICAN AGAPE FOUNDATION INC',
#  'STOA',
#  'MINDS MATTER',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF TENNESSEE',
#  'TEXAS ASSOCIATION OF SCHOOL BUINESS OFFICIALS',
#  'SIGMA THETA TAU INTERNATIONAL',
#  'BMW CAR CLUB OF AMERICA INC',
#  'KAPPA BETA GAMMA INTERNATIONAL INC',
#  'AMERICAN HARP SOCIETY',
#  'MANKIND PROJECT',
#  'SAN RAMON VALLEY EDUCATIONAL FOUNDATION',
#  'MULTI COMMUNITY DIVERSIFIED SERVICES INC',
#  'IDAHO ASSOCIATION FOR THE EDUCATION OF YOUNG CHILDREN',
#  'BIRTH NETWORK',
#  'LITTLE MISS KICKBALL INTERNATIONAL INC',
#  'NORTHERN PLAINS RESOURCE COUNCIL',
#  'STARS INC',
#  'ANCHORAGE COMMUNITY MENTAL HEALTH SERVICES',
#  'FRIENDS OF THE PARK',
#  'NATIONAL SOCIETY UNITED STATES DAUGHTERS OF 1812',
#  'UNITED WORKERS',
#  'CONSTRUCTION FINANCIAL MANAGEMENT ASSOCIATION',
#  'WEBSTER GROVES SCHOOL DISTRICT PARENT-TEACHERS ORGANIZATION',
#  'ZETA BETA TAU FRATERNITY',
#  'CAMP FIRE',
#  'FULL GOSPEL ASSEMBLIES OF AMERICA INC',
#  'SOUTHEAST SECTION OF THE NINETY NINES INC',
#  'PLANNED PARENTHOOD AFFILIATES OF CALIFORNIA INC',
#  'COMMUNITY NETWORK AFRICAN AMERICAN TELECOMMUNICATION PROFESSIONALS OF',
#  'SOROPTIMIST INTERNATIONAL OF THE AMERICAS',
#  'PHYSICIANS FOR SOCIAL RESPONSIBILITY INC',
#  'SOCIETY OF CRITICAL CARE MEDICINE',
#  'SEOUL NATIONAL UNIVERSITY ALUMNI',
#  'FREE & ACCEPTED MASONS OF MISSISSIPPI',
#  'ETA PHI BETA SORORITY INC',
#  'HOLIDAY RAMBLER RECREATIONAL VEHICLE CLUB',
#  'ASSOCIATION OF GOVERNMENT ACCOUNTANTS',
#  'PARENTS HELPING PARENTS INC',
#  'SERTOMA FOUNDATION',
#  'AMERICAN ART THERAPY ASSOCIATION',
#  'COMBAT VETERANS MOTORCYCLE ASSOCIATION',
#  'FAR EASTERN UNIVERSITY NURSING ALUMNI FOUNDATION INC',
#  'VFW AUXILIARY DEPARTMENT OF OKLAHOMA',
#  'INTERNATIONAL ALLIANCE THEATRICAL STAGE EMPLOYEES',
#  'AMERICAN ASSOCIATION OF FAMILY AND CONSUMER SCIENCES',
#  'NATIONAL PONY EXPRESS ASSOCIATION',
#  'ACTIVE 20-30 UNITED STATES AND CANADA',
#  'NATIONAL COUNCIL OF THE UNITED STATES SOCIETY OF ST VNCNT DE PAUL',
#  'VETERANS OF FOREIGN WARS DEPARTMENT OF NEW MEXICO OF THE U S',
#  'REACT INTERNATIONAL',
#  'NATIONAL SOCIETY OF THE SONS OF UTAH PIONEERS',
#  'JOBS WITH JUSTICE EDUCATION FUND',
#  'SOUTHWEST DISTRICT KIWANIS FOUNDATION',
#  'IMPROVED ORDER OF RED MEN OF TEXAS',
#  'BROTHERHOOD OF RAILROAD SIGNALMEN',
#  'KAPPA SIGMA FRATERNITY',
#  'INTERNATIONAL COSTUMERS GUILD INC',
#  'OREGON STATE GRANGE PATRONS OF HUSBANDRY',
#  'DEPRESSION AND BIPOLAR SUPPORT ALLIANCE',
#  'BLACKS IN GOVERNMENT',
#  'COALITION OF LABOR UNION WOMEN CLUB',
#  'HEARING LOSS ASSOCIATION OF AMERICA',
#  'SIGMA PI FRATERNITY INTERNATIONAL INC',
#  'AMERICAN CANCER SOCIETY INC',
#  'AMERICAN TRAIN DISPATCHERS ASSOCIATION',
#  'VOITURE NATIONALE LA SOCIETE DES 40 HOMMES ET 8 CHEVAUX',
#  'NATIONAL JUNIOR COLLEGE ATHLETIC ASSOCIATION',
#  'AMERICAN RESEARCH CENTER IN EGYPT',
#  'ROAL',
#  'NATIONAL ASSOCIATION OF POSTAL SUPERVISORS',
#  'SERRA INTERNATIONAL',
#  'AMERICAN HUMANIST ASSOCIATION',
#  'WOMEN IN AVIATION',
#  'NATIONAL DENTAL ASSOCIATION INC',
#  'CAMP QUEST INC',
#  'MEA-MFT',
#  'PARENTS WITHOUT PARTNERS INC',
#  'HISPANIC DENTAL ASSOCIATION',
#  'GARDENERS OF AMERICA INC',
#  'ANCIENT EGYPTIAN ARABIC ORDER NOBLES MYSTIC SHRINE OF N & S AMER',
#  'BENEVOLENT AND PROTECTIVE ORDER OF ELKS OF THE USA',
#  'PTA COLORADO CONGRESS',
#  'AMERICANS UNITED FOR SEPARATION OF CHURCH & STATE',
#  'KOREAN WAR VETERANS ASSOCIATION INC',
#  'PRAISE CHAPEL CHRISTIAN FELLOWSHIP CHURCHES & MINISTRIES INTL',
#  'INTERNATIONAL CAPOEIRA ANGOLA FOUNDATION',
#  'OASIS INSTITUTE',
#  'SOCIETY OF AMERICAN MILITARY ENGINEERS',
#  'SIGMA GAMMA RHO SOROITY INC',
#  'IMMIGRANT HOPE',
#  'HOOSIER CARE INC',
#  'PEOPLE TO PEOPLE INTERNATIONAL',
#  'SI ON',
#  'SISTERS NETWORK',
#  'IOTA PHI LAMBDA SORORITY INC',
#  'OMICRON KAPPA UPSILON HONORARY DENTAL SOCIETY',
#  'LOUISIANA GARDEN CLUB FEDERATION INC',
#  'ORDER OF QUETZALCOATL PLUMED SERPENT',
#  'ALPHA TAU OMEGA FRATERNITY',
#  'UNITED SPINAL ASSOCIATION INC',
#  'OMICRON KAPPA UPSILON-HONORARY DENTAL SOCIETY',
#  'CHI EPSILON',
#  'IRON PIGS MOTORCYCLE CLUB',
#  'UNITED STATES MASTERS SWIMMING INC',
#  'TRANSPORTATION ENERGY PARTNERSHIP',
#  'KLEIN SUPPORT GROUP INC',
#  'NATIONAL SOCIETY COLONIAL DAMES XVII CENTURY',
#  'DELTA TAU DELTA FRATERNITY',
#  'EARLY CHILDHOOD MUSIC ASSOCIATION',
#  'SOCIETY OF FIRE PROTECTION ENGINEERS',
#  'ASPENPOINTE INC',
#  'PTA LOUISIANA CONGRESS',
#  'SERB NATIONAL FEDERATION',
#  'CALIFORNIA RETIRED TEACHERS ASSOCIATION',
#  'YELLOWSTONE COUNTY 4-H COUNCIL',
#  'PEACEWORKS -- DANCES OF UNIVERSAL PEACE NORTH AMERICA',
#  'KAPPA ALPHA PSI FRATERNITY INC',
#  'COUNCIL OF ALBUQUERQUE GARDEN CLUBS',
#  'EXECUTIVE WOMENS GOLF ASSOCIATION',
#  'BENEVOLENT & PROTECTIVE ORDER OF ELKS OF THE USA',
#  'FOUR LETTER WORD INC',
#  'POINT MAN INTERNATIONAL MINISTRIES',
#  'ELDERLY HOUSING DEVELOPMENT AND OPERATIONS CORPORATION',
#  'SHERIFFS COMMUNITY ORGANIZED POLICING EFFORTS',
#  'SOCIETY FOR HUMAN RESOURCE MANAGEMENT',
#  'AMERICAN COLLEGE OF PHYSICIANS',
#  'MILITARY ORDER OF THE COOTIE OF THE UNITED STATES',
#  'STATE CHARTERED CREDIT UNIONS IN FLORIDA',
#  'LEAGUE OF WOMEN VOTERS OF FLORIDA',
#  'WOMEN MARINES ASSOCIATION',
#  'DAUGHTERS OF UNION VETERANS OF THE CIVIL WAR 1861 1865',
#  'ROYAL ARCH MASONS OF TENNESSEE',
#  'WASHINGTON EXPLORER SEARCH AND RESCUE',
#  'LABORERS INTERNATIONAL UNION OF NORTH AMERICA',
#  'AMERICAN BEGONIA SOCIETY',
#  'CHARTER ROAD PRODUCTIONS INCORPORATED',
#  'THE ARC OF TEXAS',
#  'FLORIDA ASSOCIATION OF ENVIROMENTAL PROFESSIONALS INC',
#  'GRAND LODGE OF MISSISSIPPI FREE AND ACCEPTED MASONS',
#  'ASSOCIATION OF EVANGELICAL GOSPEL ASSEMBLIES',
#  'ALPHA DELTA KAPPA SORORITY INC',
#  'VETERANS OF FOREIGN WARS AUXILIARY',
#  'AGENTS ASSOCIATION',
#  'U M ARMY',
#  'NATIONAL SOCIETY OF TOLE AND DECORATIVE PAINTERS INC',
#  'ORDER OF THE ALHAMBRA',
#  'NATIONAL AMBUCS INC',
#  'DAUGHTERS OF THE REPUBLIC OF TX INC',
#  'CALIFORNIA STATE CARE PROVIDERS ASSOCIATION',
#  'PAN AMERICAN ROUND TABLE OF TEXAS',
#  'SIGMA CHI FRATERNITY',
#  'WASHINGTON STATE UNIVERSITY 4-H CLUBS AND AFFILIATED ORGANIZATIONS',
#  'IZAAK WALTON LEAGUE OF AMERICA INC',
#  'ALPHA GAMMA RHO FRATERNITY',
#  'HEALTHCARE INFORMATION AND MANAGEMENT SYSTEMS SOCIETY',
#  'HOUSE OF HEROES INC',
#  'PTA MISSOURI CONGRESS',
#  'UTAH EDUCATION ASSOCIATION',
#  'MISSOURI INTERACTIVE TELECOMMUNICATIONS EDUCATION',
#  'GRAND LODGE OF MISSISSIPPI FREE & ACCEPTED MASONS',
#  'LEAGUE OF UNITED LATIN AMERICA CITIZENS',
#  'HELPING YOUNG PEOPLE EXCEL INC',
#  'INTERNATIONAL ALLIANCE THEATRICAL STAGE EMPLOYEES & MOVING PICTURE',
#  'LAFAYETTE GARDEN CLUB',
#  'NATIONAL GERONTOLOGICAL NURSING ASSOCIATION INC',
#  'ARC OF ARIZONA INC',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF TEXAS',
#  'UNITED COMMERCIAL TRAVELERS OF AMERICA',
#  'ASSOC FOR EDUCATION & REHBLTATN OF THE BLIND & VISUALLY IMPAIRED',
#  'SOCIETY FOR THE PRESERVATION AND ENCOURAGEMENT OF BARBERSHOP',
#  'ASSOCIATION FOR CONFLICT RESOLUTION',
#  'LINKS INC',
#  'VETERANS OF FOREIGH WARS OF THE UNITED STATES DEPT OF COLORADO',
#  'INTERNATIONAL ASSOCIATION OF EATING DISORDERS PROFESSIONALS FOUNDATION',
#  'NATIONAL UTILITY CONTRACTORS ASSOCIATION INC',
#  'FOLDS OF HONOR FOUNDATION',
#  'AMERICAN BUSINESS WOMENS ASSOCIATION',
#  'LABOR AND EMPLOYMENT RELATIONS ASSOCIATION',
#  'M W PRINCE HALL GRAND LODGE FREE AND ACCEPTED MASONS OF LOUISIAN',
#  'AMERICAN LEGION POST',
#  'APPA-ASSOCIATION OF HIGHER EDUCATION FACILITIES OFFICERS',
#  'CONFRERIE DE-LA-CHAINE DES ROTISSEURS LTD',
#  'GRAND CHAPTER OF TENNESSEE ORDER OF THE EASTERN STAR',
#  'ALLIANCE OF THE FRIENDS OF THE DEKALB COUNTY LIBRARY',
#  'AMERICAN RHODODENDRON SOCIETY',
#  'SAN BENITO YOUTH SOCCER LEAGUE',
#  'CATHOLIC ENGAGED ENCOUNTER INC',
#  'DANCE INITIATIVE INC',
#  'TEXAS ASSOCIATION OF SCHOOL BUSINESS OFFICIALS',
#  'TEXAS MASTER GARNENER ASSOCIATION INC',
#  'ORDER OF THE AMARANTH INC SUPREME COUNCIL',
#  'RETROUVAILLE INTERNATIONAL INC',
#  'HOLIDAY RAMBLER RECREATIONAL',
#  'UNITED TRANSPORTATION UNION',
#  'ASSOCIATION OF WOMEN IN THE METAL INDUSTRIES INC',
#  'WICHITA INDEPENDENT NEIGHBORHOODS INC',
#  'PTA CALIFORNIA CONGRESS OF PARENTS TEACHERS AND STUDENTS INC',
#  'TOOLBANK USA INC',
#  'PARENT BOOSTERS USA INC',
#  'ROYAL AND SELECT MASTERS OF GEORGIA',
#  'JOBS DAUGHTERS INTERNATIONAL',
#  'AMERICAN CRIMINAL JUSTICE ASSOCIATION LAMBDA ALPHA EPSILON',
#  'ANCIENT FREE & ACCEPTED MASON OF KANSAS',
#  'NATIONAL ALUMNAE ASSOC OF SPELMAN COLLEGE',
#  'FEDERATION OF FLY FISHERS',
#  'INTERNATIONAL FEDERATION OF PROFESSIONAL & TECHNICAL ENGINEERS',
#  'TRANSPORT WORKERS UNION OF AMERICA',
#  'PILOT INTERNATIONAL INC',
#  'CORNERSTONE CHRISTIAN MINISTRIES',
#  'DEPARTMENT OF NEVADA VETERANS OF FOREIGH WARS OF THE U S INC',
#  'JUMPSTART COALITION FOR PERSONAL FINANCIAL LITERACY',
#  'DAUGHTERS OF NORWAY',
#  'ASSOCIATION OF TRADITIONAL HOOKING ARTIST',
#  'PTSA WASHINGTON CONGRESS',
#  'NATIONAL AUTISM ASSOCIATION INC',
#  'SIGMA THETA TAU INC',
#  'UNITED STATES PONY CLUB INC',
#  'AMERICAN FEDERATION OF TEACHERS',
#  'VETERANS OF FOREIGN WARS DEPARTMENT OF ARKANSAS',
#  'NATIONAL ASSOCIATON OF CORPORATE DIRECTORS',
#  'AMERICAN COLLEGE OF PHYSICIANS SERVICES',
#  'ANCIENT FREE & ACCEPTED MASONS OF COLORADO',
#  'INTERNATIONAL ALLIANCE OF THEATRICAL STAGE EMPLOYEES LOCAL',
#  'DONUM DEI',
#  'FIGARO ANGEL NETWORK',
#  'NATIONAL CHRISTIAN INFORMATION CENTER INC',
#  'OPERATION PETS ALIVE',
#  'RAMBLE ON PRODUCTIONS',
#  'KANEOHE BAY CHAPTER NO 3',
#  'NYSSA EDUCATION ASSOCIATION',
#  'MORRISON MINISTRIES',
#  'CENTRO CULTURAL OAXACA INC',
#  'ISLAND UNIVERSITY FOUNDATION TEXAS A&M UNIVERSITY-CORPUS CHRIST',
#  'INLAND EMPIRE ASSOCIATION OF REALTIST',
#  'KMD FOUNDATION INC',
#  'LIVING PRESENCE MINISTRY INC',
#  'PURPOSE DRIVEN WOMEN OF FAITH MINISTRIES INC',
#  'BIKE 365 INC',
#  'LATEC CHARITIES INC',
#  'JOHNS CREEK HIGH SCHOOL BAND BOOSTER ASSOCIATION INC',
#  'DOUG WOODHAM DALLAS JUNIOR POLICE ACADEMY',
#  'THOUGHT NETWORK',
#  'CORTEX',
#  'BIRMINGHAM FINANCIAL COUNSELING INC',
#  'PROJECT PHILANTHROPY',
#  'SOUTHLAKE WOMENS CLUB FOUNDATION',
#  'EAPA INC',
#  'META RESEARCH INC',
#  'INLAND EMPIRE YOUTH CENTER',
#  'ASIAN AMERICANS ADVANCING JUSTICE ATLANTA INC',
#  'JOHN A HANNON MINISTRIES',
#  'FAMILIES IN TRANSITION SERVICES INC',
#  'SOS SISTERS OF STRENGTH',
#  'CHILDRENS CASE MANAGEMENT ORGANIZATION INC',
#  'IGLESIA CRISTIANA PACTO DE FE HOLLYWOOD',
#  'TANGOHELENA INCORPORATED',
#  'PORT SUSAN MIDDLE SCHOOL PTO',
#  'AMERICAN LEGION AUXILIARY RIVIERA BEACH MEMORIAL UNIT 268',
#  'CHILD AND ADULT SAFETY EDUCATION SERVICES INC',
#  'EL CRESTON MUTUAL DOMESTIC WATER CONSUMERS ASSOCIATION',
#  'ECOARTS CONNECTIONS',
#  'AMERICAN ASSOC OF UNIVERSITY WOMEN',
#  'COMMUNITY PAYEE SERVICES',
#  'KRISTIE A GONZALEZ FOUNDATION INC',
#  'LET YOUR LIFE SHINE COMMUNITY OUTREACH',
#  'EAST METRO ARTS AND CULTURE COUNCIL INC',
#  'LSJC INC',
#  'E R MINISTRY',
#  'G A P MINISTRIES',
#  'DYLAN MCNEIL FOUNDATION',
#  'EDDYS DOGS',
#  'HUMAN RESOURCE MANAGEMENT ASSOCIATION OF MARTIN CO INC',
#  'OREGON INDEPENDENT COLLEGES EMPLOYEE BENEFITS TR',
#  'WICKENBURG FOUNDATION FOR EDUCATIONAL ENRICHMENT',
#  'CRYSTAL CHILDRENS CENTER',
#  'VILONIA EAGLE BASKETBALL FOUNDATION',
#  'FILLING THE GAPS',
#  '2C2SMILE INC',
#  'LOVE DEMONSTRATED MINISTRIES INTERNATIONAL - EQUITY DEV SVCS',
#  'SIMONS ORGANIZATION FOR ANIMAL RIGHTS',
#  'REYNOLDS MIDDLE SCHOOL PTO',
#  'SCHIZOPHRENIA AND RELATED DISORDERS ALLIANCE OF AMERICA',
#  'NEVADA COUNCIL FOR AFFORDABLE RURALHOUSING',
#  'EAGLE SPRINGS ELEMENTARY PARENT TEACHER ORGANIZATION',
#  'BENEVOLENCE INDUSTRIES INCORPORATED',
#  'ANGELS IN DISGUISE CHARITABLE TRUST',
#  'RUDGEAR ESTATES SWIM TEAM INC',
#  'COMMUNITY YOUTH MINISTRIES',
#  'MINERAL AREA COUNCIL ON THE ARTS',
#  'LADIES AUXILIARY OF THE VETERANS OF FOREIGN WARS GATE CITY POST 2773',
#  'CROSSROADS COMMUNITY OUTREACH AND RESOURCE CENTER INC',
#  'THE LADY ADA FOUNDATION',
#  'COMMUNITY BIRTH COMPANION',
#  'H O N E Y INC',
#  'PASCO COUNTY ASSOCIATION OF SCHOOL ADMINISTRATORS',
#  'A THEATRE NEAR U INC',
#  'RIBBONS IN THE SKY OUTREACH MINISTRY',
#  'AMERICAN MOTHERS INC',
#  'CONSERVATION RESEARCH AND EDUCATION OPPORTUNITIES',
#  'JERRY JEROME BROWN JR SPARK THE LEADERSHIP FOUNDATION',
#  'ECAP ENTERPRISES INC',
#  'RESONATE GRACE CHURCH',
#  'CHURCHES OF OSAGE COUNTY UNITED',
#  'SAVANNAH S SMILE INC',
#  'DALLAS CASA',
#  'JOPLINS SANCTUARY AND ANIMAL RESCUE',
#  'BROOKS RAVENS YOUTH FOOTBALL & CHEER INC',
#  'RESEARCH INITIATIVE ON SOCIAL JUSTICE IN EDUCATION',
#  'SUPPORTING THE TAYLOR HOUSE',
#  'LARIMER COUNTY FUNDED HEALTH REIMBURSEMENT ARRANGEMENT VEBA TRU',
#  'GULF POWER COMPANY LABOR-MANAGEMENT COMMITTEE FUND',
#  'SOUTHSIDE ATHLETIC ASSOCIATION',
#  'PLANT YOUR DREAMS PRODUCTIONS INC A CALIFORNIA PUBLIC BENEFIT CORP',
#  'ADVANCED THERAPIES INCORPORATED',
#  'REGION 2C OF THE TEXAS STATE TEACHERS ASSOCIATION',
#  'GONZALEZ ELEMENTARY PARENT TEACHER ORGANIZATION',
#  'HEARTHFIRE ENTERPRISES INC',
#  'CALIFORNIA ALLIANCE FOR ONLINE LEARNING',
#  'VICKERY MEADOW LEARNING CENTER',
#  'MISSOURI CAREER DEVELOPMENT ASSOCIATION',
#  'AVIATOR ATHLETIC FOUNDATION',
#  'GENERATION OUTCRY INTERNATIONAL INCORPORATION',
#  'THE CLAN MACGILLIVRAY SOCIETY USA INC',
#  'ALL-STAR ORCHESTRA SUMMIT',
#  'SOUTHERN CALIF PUB SAFETY RETIREEMEDICAL TRUST',
#  'WAT DHAMMARARAM BUDDHIST ASSOCIATION INC',
#  'ZEMMA R CAMPBELL AND CHARLES CAMPBELL MEMORIAL SCHOLARSHIP FUND',
#  'COURAGEOUS HEARTS MINISTRIES INC',
#  'ALLIANCE OF THE FRIENDS OF THE DEKALB COUNTY PUBLIC LIBRARY',
#  'INGLESIDE MIDDLE SCHOOL PARENT TEACHERS ORGANIZATION INC',
#  'AMERICAN DREAM BRIGADE INC',
#  'SHEPHERDS KEEP',
#  'PHILANTHROPY INSPIRED BY THE NEEDS OF OUR COMMUNITY INC',
#  'ARIZONA COOL ROOF COUNCIL',
#  'LONESTAR RUGBY CONFERENCE',
#  'PERSONHOOD INC',
#  'HONOR BUNKER INC',
#  'ADAIR EVANGELISTIC MINISTRIES INC',
#  'AMERICAN ACADEMY OF CRANIOMAXILLOFACIAL SURGEONS',
#  'AMERICAN MOCK TRIAL ASSOCIATION',
#  'GREATER MIAMI CHAPTER USNAAA',
#  'COMMUNITY TREASURES',
#  'MILNE INSPIRATION CENTER',
#  'EMERSON AVENUE COMMUNITY GARDEN CLUB INC',
#  'SNOHOMISH COUNTYS FINEST A WASHINGTON NONPROFIT CORPORATION',
#  'POPE COUNTY LIBRARY SYSTEM FOUNDATION INC',
#  'TIMBERLY TRUST INC',
#  'SHREE SWAMINARAYAN SATSANG MANDAL OF FLORIDA',
#  'BRIDGETS CRADLES FOUNDATION',
#  'BLUE TURTLE GREEN BIRD SOCIETY INC',
#  'BF PROPERTY TR',
#  'HISTORICAL FIRE STATION 19 FOUNDATION',
#  'TAOS ART & CULTURAL DISTRICT INC',
#  'THE@FOUNDATION FOR COMMUNITY DEVELOPMENT AND EMPOWERMENT',
#  'FRIENDS OF JACKSON COUNTY ANIMAL SHELTER PETS',
#  'BLACKS MILL ELEMENTARY SCHOOL PARENT TEACHER ORGANIZATION',
#  'HEARTS UNITE THE GLOBE INCORPORATED',
#  'HOME AWAY FROM HOME INC',
#  'INITIATIVE SAVE AFRICAN CHILDREN',
#  'SUTTON SENIOR ANNEX INC',
#  'CARSON CITY CARES',
#  'NORTHERN CALIFORNIA VETERANS SUPPORT GROUP',
#  'AQUINAS EDUCATION AND FORMATION TR',
#  'SEEPOLITICAL INC',
#  'ESCONDIDO CLUB INC',
#  'ADULTS MANKIND ORGANIZATION INC',
#  'VIETNAMESE AMERICAN HOUSTON CHAMBEROF COMMERCE',
#  'HONOLULU PROFESSIONALS FOUNDATION',
#  'UNDERGROUND UTILITY CONTRACTORS OF FLORIDA ANDREW SCOTT JOHNSON',
#  'GYPSY CANINE RESCUE',
#  'EL LLANO ESTACADO RESOURCE CONSERVATION & DEVELOPMENT COUNCIL',
#  'AMICALOLA EMC TR',
#  'BOX ELDER UTAH COMMUNITY DEVELOPMENT CORPORATION',
#  'SEATTLE JEWISH GIRLS HIGH SCHOOL',
#  'MILE HIGH GERMAN SHORTHAIRED POINTER RESCUE',
#  'LIVING BRIDGES MINISTRY CORPORATION',
#  'MARVELOUS LIGHT EMPOWERMENT ASSOCIATION INC',
#  'SECOND TABLE MINISTRIES',
#  'SPECIAL FRIENDS EXTENDED INC',
#  'WELLNESS WORKS PDX',
#  'GREATER SW FLORIDA PARADISE IOWA CLUB',
#  'JOSEPH SMITH III & ISRAEL A SMITH HISTORICAL SOCIETY',
#  'AMATEUR ATHELTIC UNION OF THE UNITED STATES INC',
#  'PIERCE COUNTY AMATEUR RADIO COMMUNICATION SERVICES',
#  'EAST HANDLEY ELEMENTARY PTA',
#  'EXERCISE 4 LIFE INC',
#  'PEOPLE HELPING PEOPLE UNITED INC',
#  'SOUTH LOUISIANA CENTER FOR THE ARTS',
#  'ORGANIZATION OF IRANIAN AMERICAN COMMUNITIES INC',
#  'TWENTYNINE PALMS HIGH SCHOOL MUSIC BOOSTER ASSOCIATION',
#  'NOTHING WITHOUT JESUS',
#  'TROPICAL ROSE SOCIETY',
#  'SOMALI COMMUNITY SELF MANAGEMENT',
#  'ORANGE COUNTY MASTER GARDENERS',
#  'VALLEY ANIMAL HAVEN & ADOPTION CENTER',
#  'MISSISSIPPI SYMPHONY ORCHESTRA ASSOCIATION',
#  '3RD OSS BOOSTER CLUB',
#  'ARK OF HOPE',
#  'CHICO OAKS ADVENTIST PRESCHOOL',
#  'IMPACT TEAMS INTERNATIONAL',
#  'URBAN MANAGEMENT ASSISTANTS OF CENTRAL TEXAS',
#  'URBAN CITY FRESH CO',
#  'HILLIARD BAND BOOSTERS INC',
#  'TOMBSTONE LIONS CLUB',
#  'MAUNATUL MUSLIMEEN SOCIETY OF CALIFORNIA',
#  'MID AMERICA TEEN COMMUNITY EMERGENCY RESPONSE TEAM TEEN CERT',
#  'WASHINGTON STAMPEDERS LLC',
#  'PARKVILLE ROTARY CLUB ROTARY INTERN ATIONAL',
#  'NICK & FRIENDS SARCOMA FOUNDATION INC',
#  'CINEMA NAPA VALLEY',
#  'COOL GIRLS SCIENCE AND ART CLUB',
#  'RAY PACK RESCUE INC',
#  'VICTORIA BRANCH 1221 VICTORIA TEXAS OF THE UNITED STATES OF AMERICA',
#  'PIONEER CEMETERY CARE TR',
#  'TEXAS BRAHMAS YOUTH HOCKEY ASSOCIATION',
#  'ASSOCIATION OF RETIREMENT ORGANIZATIONS IN HIGHER EDUCATION',
#  'ECOLOGY IN CLASSROOMS AND OUTDOORS NORTHWEST',
#  'APPLE VALLEY SOCCER CLUB',
#  'AUSTIN YOUTH ORCHESTRA',
#  'FORT BEND TEXANS SPORTS ASSOCIATION',
#  'GLOBAL ANIMAL RESCUE FUND INC',
#  'PUBLISHERS ASSOCIATION OF LOS ANGELES',
#  'KENNESAW DREAM FOUNDATION INC',
#  'TORCH ACADEMY',
#  'OLYMPIC MOUNTAIN EARTHWISDOM CIRCLE',
#  'MILTON HIGH SCHOOL 50TH CLASS REUNION MEMORIAL SCHOLARSHIP TR',
#  'ONYX FINE ARTS COLLECTIVE',
#  'ALEXANDER ART SPACE INCORPORATED',
#  'PAUL BASCH MEMORIAL FOUNDATION',
#  'TANGI HUMANE SOCIETY',
#  'MARION COUNTY PUBLIC SAFETY ASSISTANCE TR INCORPORATED',
#  'INTERNATIONAL ALLIANCE OF THEATRICAL STAGE EMPLOYEES LOCAL 7',
#  'PRINCIPAL THINGS MINISTRY',
#  'DALLAS COUNTY ALLIANCE SUPPORTING HEALTH',
#  'GLASS TO DIAMONDS',
#  'THE AMERICAN LEGION POST 81',
#  'WALTER F MEIER COUNCIL 22ROYAL AND SELECT MASTERS',
#  'HARRY A BISZANTZ MEMORIAL CENTER FOR THOROUGHBRED RETIREMENT',
#  'WILLIAM MARSH RICE UNIVERSITY',
#  'ANGELS RESCUING KRITTERS',
#  'FORCED EXOTIC ANIMAL RELOCATION AND CENTER FOR EDUCATION INC',
#  'UNITED STATES SEAGOING MARINE ASSOCIATION',
#  'ARROWHEAD CHARITIES CORPORATION',
#  'INTERNATIONAL ASSOCIATION OF LIONSC CLUBS',
#  'GLADYS POLK ELEMENTARY PTO INC',
#  'HAYTI CENTRAL SCHOOL PARENT CHAPTER',
#  'OASIS OF VINE CITY INC',
#  'LIVING WATER MINISTRIES OF PERRY INC',
#  'BEYOND NEWTON INC',
#  'GEORGIA PRIME FASTPITCH SOFTBALL ORGANIZATION INC',
#  'DECATUR BULLDOG ATHLETIC BOOSTER CLUB',
#  'DELTA ZETA SORORITY',
#  'CEDAR MOUNTAIN NORDIC SKI CLUB',
#  'LEGACY GYMNASTICS BOOSTER CLUB',
#  'MIDWESTERN COLLEGE',
#  'BAKERSFIELD ASSOCIATION OF SPEECH PATHOLOGISTS AND AUDIOLOGISTS',
#  'MOUNTAIN VISTA MEDICAL CENTER AUXILITARY',
#  'GOOD GIRLS CLUB OF ATLANTA',
#  'RESIDENTS NORCO URGING PROTECTION RURAL & ANIMAL KEEPING LIFESTYLES',
#  'TOGETHER AS ONE PHILANTHROPIC SOCIETY',
#  'SERVINGHIM HEALTHCARE INTERNATIONAL MINISTRIES',
#  'JEMEZ PUEBLO ANIMAL RESCUE',
#  'A MILLION MATTERS INC',
#  'ONI OCHUN CULTURAL CENTER',
#  'PITKIN - EAGLE - GARFIELD DAMAGE PREVENTION COUNCIL',
#  'BRIDGES MIDDLE SCHOOL',
#  'SAVED ME 2 INC',
#  'K-STATE UNION CORPORATION',
#  'NEVADA BRAIN BEE ASSOCIATION',
#  'VISTA BEAUMONT PTO',
#  'TX VIP INC',
#  'IN TOUCH RESIDENTIAL YOUTH CENTER',
#  'SOCIETY HISPANIC PROFESSIONAL ENGINEERS TEXAS BAY AREA CHAPTER',
#  'GIFT PLANNING INSTITUTE',
#  'SOMEPLACE SPECIAL INC',
#  'AMBASSADORS FOR CHRIST WORSHIP CENTER INC',
#  'AHUAS CLINIC FOUNDATION',
#  'WATER IN THE DESERT INC',
#  'HILLSBOROUGH ASSOCIATION OF SCHOOL ADMINISTRATORS',
#  'BACKIN HAITI INC',
#  'OPEN GRAVES MISSIONS',
#  'SYRIA RELIEF & DEVELOPMENT',
#  'AFRICAN AMERICAN WELLNESS PROJECT',
#  'UNITED CHRISTIAN MINISTRIES INC',
#  'SPECIAL DELIVERY DENTAL CARE INC',
#  'WALTER SKINNER MINISTRIES INC',
#  'SOUTHERN CALIFORNIA INDUSTRIAL MUTUAL AID ORGANIZATION',
#  'HODARI SCHOLARS FOUNDATION',
#  'AABY FOUNDATION',
#  'LOWER DOWNTOWN DENVER ARTS ASSOCIATION INC',
#  'HUMANITARIAN AID PROJECT FOR CUBAS',
#  'GODS WORK FOR MAN',
#  'ANAMCHARA MINISTRIES',
#  'MISSOURI YOUTH RUGBY',
#  'KAUAI VOICES INC',
#  'CRESTED BUTT MT CRESTED BUTTE BARTENDERS AND SERVERS ASSOCIATION',
#  'SICKLE CELL ASSOCIATION OF HOUSTON',
#  'SAH SOCCER',
#  'MISSISSIPPI COUNTY INTERAGENCY ACOUNCIL',
#  'COLLEGE PLACE MIDDLE SCHOOL MUSIC BOOSTERS',
#  'THE ESOTERICS',
#  'STANFORD PROFESSIONALS IN REAL ESTATE NC',
#  'MEMPHIS INLINE RACING INCORPORATED',
#  'CENTRAL PENINSULA HOCKEY OFFICIALS ASSOCIATION',
#  'FLORIDA DISTRICT VIRTUAL INSTRUCTION PROGRAM NETWORK',
#  'POWER OF FAITH MINISTRIES LLC',
#  'CIRCLE OF UNITY LA INC',
#  'STOP CHILD ABUSE TODAY GROUP OF MONTAGUE COUNTY',
#  'DESARROLLO CRISTIANO INC',
#  'GARDEN OF INNER PEACE',
#  'OKLAHOMA SOCIETY OF ASSOCIATION EXECUTIVES EDUCATION AND RESEARCH',
#  'MY LIFE TESTIMONY MINISTRIES DBA MLT MINISTRIES',
#  'CLERGY COMMUNITY FOR CHILDREN AND YOUTH COALITION',
#  'RED RIVER SPCA',
#  'JAPAN ARTS INC',
#  'DAIR INC',
#  'ASSOCIATION OF VETERANS EDUCATION CERTIFYING OFFICIALS',
#  'GARDEN CITY TRAP & SKEET CLUB INC',
#  'NONPROFIT ORGANIZATION BUILDING LASTING ENRICHMENT INC',
#  'UNITED COALITION FOR DECENCY',
#  'VIANDE BOUCANEE INC',
#  'PROJECT MUSZED',
#  'LEADERSHIP EMPOWERMENT GROWTH ACHIEVEMENT COMES FROM OUR YOUTH',
#  'HARRIS-MURPHY YOUTH FOUNDATION',
#  'LAY LAKE HOME OWNERS AND BOAT OWNERS HOBO ASSOCIATION INC',
#  'HOPE KENYA INC',
#  'SCOPERS',
#  'COURT APPOINTED SPECIAL ADVOCATES IN THE HEART OF TEXAS',
#  'MCALLEN INTERNATIONAL MUSEUM',
#  'PACIFIC HAWAIIANOLOGY INC',
#  'TEXAS TECH ASSOCIATION OF NATURAL RESOURCE SCIENTISTS',
#  'SOUTHWEST AIRLINES PILOTS ASSOCIATION VOLUNTARY EMPLOYEES',
#  'BETTER CAUSE',
#  'WALKER COUNTY AMATEUR RADIO EMERGENCY SERVICE',
#  'COLUMBIA COUNTY ORCHESTRA ASSOCIATION',
#  'DSUSD-STATE PRESCHOOL PARENT ADVISORY COMMITTEE',
#  'HEARTBEAT MINISTRIES',
#  'WHITE STATION HIGH SCHOOL PARTNERS IN EDUCATION',
#  'TEMPE OLD DEVILS RUGBY CLUB',
#  'RUFFIN EMPLOYEE SCHOLARSHIP',
#  'PASTORAL CARE ASSOCIATES',
#  'GREATER WACO CHILDRENS CHOIR',
#  'CAMELBACK DESERT SCHOOL PARENT ORGANIZATION SCOTTSDALE',
#  'HUMEM STATE FOUNDATION',
#  'FURRST AND FURRMOST POOCH SANCTUARY INC',
#  'TG 105 INC',
#  'CENTER FOR ISLAMIC SCIENCES',
#  'NATIONAL PROFESSIONAL SCIENCEMASTERS ASSOCIATION',
#  'HOME EDUCATORS ALLIANCE FORRESOURCES AND TRAINING OF TEXAS INC',
#  'HUITZILOPOCHTLI DANCING AND TEACHING OUR INDIGENOUS HERITAGE',
#  'ORTHODOX CHRISTIAN MINISTRIES INC',
#  'TENNESSEE PROFESSIONAL INVESTIGATORS ASSOCIATION',
#  'EBERHART FOUNDATION INC',
#  'TFT',
#  'SAMUEL Z STONE CIPR SUPPORT TRUST',
#  'SHELDON LITTLE LEAGUE',
#  'ABOVE THE SEAS LLC',
#  'GRACE ACADEMY OF CARTERSVILLE INC',
#  'IDAHO PARTNERSHIP ON HIGHER EDUCATION AND DISABILITY',
#  'SOLE TO SOUL',
#  'I AM MORE THAN INCORPORATED',
#  'CIA ALL-STAR CHEER BOOSTER CLUB INC',
#  'POM-POMS CASTLE',
#  'JANE KANESHIRO SOZAN KAI',
#  'JEFFERSON COUNTY MEDICAL ADVOCACY & SERVICE HEADQUARTERS',
#  'WORLDWIDE BREAST CANCER',
#  'BONITA COUNTRY DAY SCHOOL A CALIFORNIA NON-PROFIT CORPORATION',
#  'GRAND PRAIRIE CITIZEN POLICE ACADEMY ALUMNI ASSOCIATION',
#  'AIR WARRIOR COURAGE FOUNDATION',
#  'EAST WEST CHRISTIAN OUTREACH INC',
#  'GLOBALARTS',
#  'CHRIST CHURCH CHRISTIAN SCHOOL',
#  'EXECUTIVE WOMENS GOLF LEAGUE SEATTLE CHAPTER',
#  'GREATER NEVADA MARINE CORPS LEAGUE DET 186',
#  'UNITED METHODIST SOCIAL SERVICES INC',
#  'LAWRENCE W CROSS MIDDLE SCHOOL PTO',
#  'CASCADIA PARENT TEACHER ORGANIZATION',
#  'LIMPOPO WRITING PROJECT',
#  'MORAL HELPING HAND INC',
#  'UNITED WAY OF WASHINGTON COUNTY UTAH INC',
#  'UNITED STATES MERCHANT MARINE ACADEMY ALMUNI ASSOC',
#  'AVALON HEALTH CARE INC WELFARE PLAN TR',
#  'OPERATION NEVER FORGOTTEN INC',
#  'SCOTTISH RITE CATHEDRAL PRESERVATION ASSOCIATION INC',
#  'ROTARY CLUB OF DURHAM FOUNDATION',
#  'MIDDLE GEORGIA CENTER FOR INDEPENDENT LIVING INC',
#  'ALUMNI AND VOLUNTEER CORPORATION OF THE CALIFORNIA BETA',
#  'UTSALADY BOOSTER CLUB',
#  'TURN IT GOLD',
#  'IM MODELING A NEW IMAGE',
#  'MARTIAL ARTS CENTER FOR STUDENTS WITH SPECIAL NEEDS INC',
#  'FAMILY RESOURCE CENTER OF TRUCKEE',
#  'NATE WASSERMAN CAMP FUND',
#  'FRANCES RIDLEY HAVERGAL TRUST',
#  'SANTA CRUZ REALTOR BENEVOLENT FOUNDATION',
#  'PROFESSIONAL APPRAISERS INFORMATION NEXUS OF NEVADA',
#  'CHI EPSILON 35',
#  'COLORADO PARROT RESCUE INC',
#  'ALL POINTS WEST GERMAN SHORTHAIRED POINTER RESCUE',
#  'UNIVERSITY BAPTIST CHURCH OF HOUSTON FOUNDATION INC',
#  'LOS ANGELES POLICE DEPT SOUTHEAST DIVISION POLICE ACTIVITIES LEAGUE',
#  'SAN GABRIEL MOUNTAINS HERITAGEASSOCIATION',
#  'CENTER FOR MEDIATION PEACE AND RESOLUTION OF CONFLICT-INTERNATION',
#  'IMAGE PRODUCTIONS INC',
#  'WOMENS BUSINESS ALLIANCE',
#  'AMERICAN LEGION POST 81',
#  'BOULDER GREEN BUILDING GUILD',
#  'OPERATION SPAY BAY INC',
#  'PAIS USA INC',
#  'PREMIERLIFE',
#  'FARMERSVILLE ROTARY CLUB',
#  'RURAL COMMUNITY HOSUING DEVELOPMENT CORPORATION',
#  'GENERAL FEDERATION OF WOMENS CLUBS',
#  'EQUINE PARTNERS OFFERING NEW AWARENESS INC',
#  'LIVING WORD AND PRAISE SANCTUARY',
#  'SPELL-CITY ENGLISH SPELLING SCHOOL',
#  'GANG REDUCTION INTERVENTION TEAM',
#  'SOUTH SEATTLE WOMENS HEALTH FOUNDATION',
#  'TEXAS AREA FUND FOUNDATION INC',
#  'INTERNATIONAL GYMNASTICS BOOSTER CLUB INC',
#  'SAN LUIS OBISPO WOMENS SOCCER',
#  'SEATTLE-EAST TIMOR RELIEF ASSOCIATION',
#  'R O Y RECLAIMING OUR YOUTH',
#  'MONTANA CREDIT UNION LEAGUE GROUP BENEFITS TR',
#  'ANNIES PET RESCUE',
#  'LOUISIANA FOLKLORE SOCIETY',
#  'GEOCHINA CIVIL INFRASTRUCTURE ASSOCIATION',
#  'KRAKEN QUARTET NFP',
#  'COLLIER HARVEST FOUNDATION',
#  'ALPHA OMEGA INTERNATIONAL DENTAL FRATERNITY INC',
#  'BROTHERHOOD OF LOCOMOTIVE ENGINEERS & TRAINMEN',
#  'LUCK & LOESSIN COLLECTION TR',
#  'U S NAVAL SEA CADET CORP HOUSTON DIVISION',
#  'CHRISTIAN EDUCATION DEVELOPMENT COMPANY',
#  'MILITARY ORDER OF THE COOTIE OF THE UNITED STATES CHUCKANUT PUP TENT18',
#  'SILOAM SPRINGS CRISIS RESPONSE UNIT',
#  'WHATS IMPORTANT NOW FOUNDATION',
#  'DARE TO BE DIFFERENT INC',
#  'W H GROVE HOME TR 360 8336036000',
#  'FIDOS4HEROES INC',
#  'FOOD EQUALITY INITIATIVE INC',
#  'RURAL ECONOMIC DEVELOPMENT COMMISSION OF NEVADA',
#  'CIRCLE RANCH INCORPORATED',
#  'LONE STAR BLACK BELT ACADEMY PARENTS ASSOCIATION',
#  'SOUTHERN SUSTAINABLE AGRICULTURE WORKING GROUP INC',
#  'HOMELESS YOUTH WORKGROUP OF YAKIMA COUNTY',
#  'ROGUE VALLEY CHAPTER OF THE AMERICAN COUNCIL OF THE BLIND OF',
#  'COLLEGIATE LIFE INVESTMENT FOUNDATION',
#  'HURST-EULESS-BEDFORD SPORTS HALL OF FAME INC',
#  'NATIVITY INC',
#  'PINEY GROVE MIDDLE SCHOOL PTSA',
#  'HOUSE OF GOD',
#  'COMMUNITIES IN SCHOOLS OF CENTRAL GEORGIA INC',
#  'SOUTH TEXAS YOUTH SOCCER ASSOCIATION',
#  'MEN & WOMEN 4 CHANGE SOCIAL CLUB',
#  'MCKINLEY HIGH SCHOOL ALUMNI ASSOCIATION',
#  'SUFFICIENCY OF SCRIPTURE MINISTRIES',
#  'GREATER WESLEY CHAPEL CHAMBER OF',
#  'BIRCH LANE APARTMENTS INC',
#  'SOUTHWESTERN FINANCE ASSOCIATION',
#  'BUTTERFLY RANCH INCORPORATED',
#  'RECOVERY DOG NETWORK',
#  'MIKE FORCE ASSOCIATION INC',
#  'CLEARWATER CHAPTER OF THE NORTHWEST GOLD PROSPECTORS',
#  'CATHOLIC CHARITIES OF SAN JOSE',
#  'CALIFORNIA SACA FOUNDATION',
#  'ATLANTA RONALD MCDONALD HOUSE CHARITIES INC',
#  'MUSICAL INSTITUTE FOR KNOWLEDGE AND EDUCATION',
#  'S ENCHILL WELLNESS',
#  'LAKE SAINT LOUIS POST 10350 VETERANS OF FOREIGN WARS OF THE',
#  'ADVOCATES FOR VICTIMS OF ABUSE',
#  'TEAM TEST BOOSTER CLUB',
#  'TCAMP PLUS INC',
#  'TRINITY SERVICES FOUNDATION INC',
#  'COALITION FOR EQUITABLE WATER RATES',
#  'CENTRAL BAND OF CHEROKEE',
#  'BUENA PARK SCHOOL DISTRICT EDUCATION FOUNDATION',
#  'RPHS ALL-SPORTS BOOSTER CLUB',
#  'SHARP ELECTRIC VEBA TR',
#  'NOOKSACK ELEMENTARY PTA 8 4 39',
#  'INTERNET SAFETY KIDS',
#  'PEACEMAKERS',
#  'WAIF WOMENS COMMUNITY SERVICE',
#  'MEALSHARE USA',
#  'A DOLLAR TODAY INC',
#  'KUNTUR WASI INC',
#  'LAKE FORREST PREPATORY PARENT TEACHERS ASSOCIATION INC',
#  'CHRISTIAN DISCIPLING MINISTRIES INC',
#  'MOWA BAND OF CHOCTAW INDIAN COMMISSION',
#  'NATIONAL ASSOCIATION OF COLLEGIATE GYMNASTICS COACHES - WOMEN',
#  'ACTION UNITED FOR ENTERTAINERS AND DIVERSE ARTIST',
#  'CELEBRATION TABERNACLE INC',
#  'PARENTS RIGHTS IN EDUCATION',
#  'EDWARD HYNES CHARTER SCHOOL PTO INC',
#  'ALAMO CITY OPERA',
#  'EAGLES WINGS CHRISTIAN LIBRARY INC',
#  'TEXAS INDEPENDENT ATHLETIC ASSOCIATION',
#  'CHI EPSILON 55',
#  'SCV CHINESE SCHOOL',
#  'PACIFIC STAGES',
#  'NANAS CHILDRENS HOME INC',
#  'OUR SISTERS PROJECT',
#  'PHAC NO 1 INC',
#  'EDUCATIONAL SERVICES HAWAII FOUNDATION',
#  'LONE STAR ART ALIIANCE OF TEXAS',
#  'PARK PLACE PARENTS ASSOC',
#  'JEFFERSON RISE INC',
#  'POLYCLINIC COMMUNITY HEALTH',
#  'ANNAS GRACE FOUNDATION INC',
#  'ALASKA DIVE SEARCH RESCUE AND RECOVERY TEAM',
#  'INTERNATIONAL ASSOCIATION OF BROADCAST MONITORS',
#  'FRIENDS OF JIM LUCAS CHECOTAH PUBLIC LIBRARY INC',
#  'ATLANTA ELITE YOUTH ASSOCIATION',
#  '2 X 2 INC',
#  'NAMI TEXAS PANHANDLE INC',
#  'THE PATAGONIA WOMANS CLUB',
#  'WELCOME HOME HOUSING INC',
#  'NATIONAL FEDERATION OF THE BLIND OF UTAH',
#  'EXPECTCHANGE NONPROFIT CORPORATION',
#  'OKLAHOMA FAMILY LEGAL ADVOCATES INC',
#  'ALICE G HARRISON MEMORIAL TRUST',
#  'SOCIETY OF PEDIATRIC NURSES',
#  'HOMEWARD BOUND DOG RESCUE WESTERN O KLAHOMA INC',
#  'AMBASSADOR TRUST',
#  'AMERICAN ZANG EDUCATION PRESERVATION FOUNDATION',
#  'FISH FOOD FEEL GOOD',
#  'DIANA ORTEGA LLABRES BURN FOUNDATION',
#  'CROSSROADS DOWNTOWN PARTNERSHIP INC',
#  'RED SHOE PROJECT INC',
#  'HEALING THROUGH EXPRESSIVE ARTS INC',
#  'PEACEMAKERS LOVE FOUNDATION',
#  'CASSAR FAMILY FOUNDATION',
#  'SULLIVAN CEMETERY FUND TR',
#  'INSIDE-OUT MINISTRIES INC',
#  'AFRICAN AMERICAN DANCE REVIEW',
#  'ST XENIA OF PETERSBURG RUS ORTH CHURCH',
#  'NATIVE HOOVES CORP',
#  'COVENANT FAITH OUTREACH MINISTRIES INCORPORATION',
#  'ENTERTAINMENT HALL OF FAMES MUSEUM OF LAS VEGAS',
#  'EMERALD CITY HELPING OTHERS INCORPORATED',
#  'U S D 108 ENDOWMENT ASSOCIATION INC',
#  'LOVE HOME INC',
#  'JIM H GREEN KIDZ HARBOR INC',
#  'COMBAT VETERANS MOTORCYCLE ASSOCIATION CHAPTER 29-4',
#  'SAVE POUND ANIMALS THRU RESCUE & EDUCATION',
#  'EMILY S PLACE INC',
#  'SIGMA ALPHA CHRISTIAN WOMENS SOCIAL CLUB',
#  'HAMMIS FAMILY CHARITIES',
#  'FOUNTAIN OF LIFE CHRIST CENTER MINISTRIES INC',
#  'MIRACLE LEAGUE OF CAMDEN COUNTY',
#  'FORGOTTEN SINNERS',
#  'EVERY VICTIM EVERY TIME',
#  'PINE GROVE ELEMENTARY PTA',
#  'HAWAII PROSTATE CANCER COALITION',
#  'EMPOWERED PRESENCE NETWORK',
#  'ACADEMY OF TRANSDISCIPLINARY LEARNING AND ADVANCED STUDIES INC',
#  'STICKTOITIVE',
#  'UNITED AUTHORS ASSOCIATION',
#  'MESQUITE FASTPITCH SOFTBALL ASSOCIATION INC',
#  'PINECREST ELEMENTARY PTA',
#  'KIDS CONQUERING SICKLE CELL DISEASE FOUNDATION INC',
#  'MEROS ACADEMY',
#  'HOMEAID HOME BUILDERS CARE INC',
#  'AMARILLO HOCKEY ASSOCIATION INC',
#  'SERENE HILLS ELEMENTARY SCHOOL PARENT TEACHER ORGANIZATION',
#  'BRAIN INJURY PRODUCTIONS INC',
#  'GENERATION JOY FOUNDATION',
#  'FAMILY ADVOCATE CENTER & EMPOWERMENT SERVICES OF MEMPHIS',
#  'HAVE A SKATE WITH BOB FOUNDATION',
#  'R P M DANCE INC',
#  'IN HIS TIME INC',
#  'A F T E R INC',
#  'OREGON RAIL USERS LEAGUE',
#  'TWO GS ENTERPRISE',
#  'HMONG 18 COUNCIL OF SOUTH ARKANSAS',
#  'SAGUARO SKIPPERS',
#  'LEWIS COUNTY SHERIFFS OFFICE ASSOCIATION',
#  'COFFEE QUALITY INSTITUTE',
#  'FLINT ELECTRIC MEMBERSHIP CORPORATION VEBA TR',
#  'LEGACY CHRISTIAN ACADEMY INC',
#  'NORTH FOREST BULLDOGS YOUTH SPORTS',
#  'XI ETA LAMBDA EDUCATION AND ECONOMIC DEVELOPMENT FOUNDATION',
#  'OBSESSIVE COMPULSIVE FOUNDATION INC',
#  'ARTONDALE PTA',
#  'G Y R L S INC',
#  'ROBERT & BLANCHE GORDON FAMILY AFFILIATED FUND OF THE OKLAHOMA',
#  'SHERIDAN SKI CLUB',
#  'EUREKA CHRISTIAN HEALTH OUTREACH INC',
#  'ANGLERS FOR THE CURE CHARITABLE TR',
#  'WOODLAND FORREST ELEMENTARY PTA',
#  'UNITED REGIONAL HEALTH CARE SYSTEM AUXILIARY',
#  'ECOLOGICAL RESEARCH AND ACTION FOUNDATION INC',
#  '1150 WEBSTER STREET INC',
#  'FALLON COUNTY LIBRARY INC',
#  'Y AND Y DEVELOPMENT',
#  'BATTLE BORN BOXING CLUB INC',
#  'CATERING TO AFRICANS IN NEED',
#  'JOSEPH LEWICKI FOUNDATION',
#  'MEMPHS SHELBY CO SEC NCNW INC',
#  'HALOALAUNUIAKEA EARLY LEARNING CENTER',
#  'TULARE POLICE ATHLETIC LEAGUE PAL',
#  'AVERIE FOUNDATION',
#  'ETHOS MINISTRIES',
#  'BROTHERHOOD OF MAINTENANCE OF WAY EMPLOYES DIVISION',
#  'TEXAS COASTAL VOLLEYBALL ASSOCIATION',
#  'WEAVER FOUNDATION-GEORGIA MATTSON MEMORIAL SHELTER',
#  'HEALTH ALLIANCE',
#  'NEWCREEATIONS MINISTRIES',
#  'DATIL AREA COMMUNITY ADVISORY BOARD',
#  'BATON ROUGE UNIT OF PARLIAMENTARIANS',
#  'NORTH FORK ROAD COALITION FOR HEALTH AND SAFETY',
#  'WOMENS COUNCIL OF REALTORS - NWOAR CHAPTER',
#  'MEMPHIS EMPOWERMENT INITIATIVE',
#  'REVELATIONS-REVEALED TRUTH INC',
#  'MORRO BAY IN BLOOM INCORPORATED',
#  'OREGON STATE ASSEMBLY OF THE ASSOC OF SURGICAL TECHNOLOGISTS',
#  'THE IDAHO ASSOCIATION OF PLANT PATHOLOGY',
#  'BRUCETON MASONIC LODGE 731 OF FREE AND ACCEPTED MASONS',
#  'SCOUTING FOR THE VALLEY',
#  'DOMINICS DESIGNATED DRIVER',
#  'AKWA IBOM STATE ASSOCIATION - OREGON & WASHINGTON',
#  'NORTHWEST MUSIC ASSN',
#  'YOUTH MUSIC ORGANIZATION',
#  'BOSHEARS MEMORIAL FLY-IN INC',
#  'ALWANI GROUP FOUNDATION INC',
#  'THINK WILDLIFE INITIATIVE SAVING HABITAT',
#  'DR AQUINO FOUNDATION TRAINING BRAINS',
#  'G1 SPORT SUPPORT',
#  'CLEAR CREEK ISD GROUP',
#  'ANPHON CORPORATION',
#  'GREENE CEMETERY ASSOCIATION INC',
#  'NATIONAL COALITION OF 100 BLACK WOMEN',
#  ...]

# %%
# Replace in dataframe
for name in Names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(name,"Other")

# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# Other                                             19803
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
#                                                   ...
# PENN STATE ALUMNI ASSOCIATION                         5
# PTA GEORGIA CONGRESS                                  5
# HIGH TWELVE INTERNATIONAL                             5
# ARROW CHILD AND FAMILY MINISTRIES                     5
# FLORIDA FAMILY CHILD CARE HOME ASSOCIATION INC        5
# Name: NAME, Length: 403, dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
counts = application_df['APPLICATION_TYPE'].value_counts()
counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
counts = application_df['APPLICATION_TYPE'].value_counts()
counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
counts = application_df['APPLICATION_TYPE'].value_counts()
counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE

application_types_to_replace = list(counts[counts<500].index)
application_types_to_replace
# Out:
# ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# %%
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
counts1 = application_df['CLASSIFICATION'].value_counts()
counts1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1236        1
# C4200        1
# C4500        1
# C1732        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
counts2 =counts1[counts1>1]
counts2
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1235        9
# C1237        9
# C7210        7
# C4100        6
# C2400        6
# C1720        6
# C1600        5
# C1257        5
# C1260        3
# C0           3
# C2710        3
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = list(counts1[counts1<100].index)
classifications_to_replace
# Out:
# ['C2800',
#  'C7100',
#  'C1300',
#  'C1280',
#  'C1230',
#  'C1400',
#  'C2300',
#  'C7200',
#  'C1240',
#  'C8000',
#  'C7120',
#  'C1500',
#  'C1800',
#  'C6000',
#  'C1250',
#  'C8200',
#  'C1278',
#  'C1238',
#  'C1235',
#  'C1237',
#  'C7210',
#  'C4100',
#  'C2400',
#  'C1720',
#  'C1600',
#  'C1257',
#  'C1260',
#  'C0',
#  'C2710',
#  'C1234',
#  'C1246',
#  'C1267',
#  'C1256',
#  'C3200',
#  'C2380',
#  'C1728',
#  'C1248',
#  'C1580',
#  'C1570',
#  'C2570',
#  'C1370',
#  'C1245',
#  'C3700',
#  'C4120',
#  'C8210',
#  'C1283',
#  'C5200',
#  'C2170',
#  'C2500',
#  'C1900',
#  'C2190',
#  'C6100',
#  'C2561',
#  'C2600',
#  'C1820',
#  'C1236',
#  'C4200',
#  'C4500',
#  'C1732',
#  'C2150']

# %%
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df,dtype=float)
application_df.head()
# Out:
#    STATUS  ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0       1     5000  ...                       1.0                       0.0
# 1       1   108590  ...                       1.0                       0.0
# 2       1     5000  ...                       1.0                       0.0
# 3       1     6692  ...                       1.0                       0.0
# 4       1   142590  ...                       1.0                       0.0
#
# [5 rows x 461 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
y
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %%
# Split the preprocessed data into a training and testing dataset
X = application_df.drop('IS_SUCCESSFUL', axis=1).values
X
# Out:
# array([[1.0000000e+00, 5.0000000e+03, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 1.0859000e+05, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 5.0000000e+03, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        ...,
#        [1.0000000e+00, 5.0000000e+03, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 5.0000000e+03, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 3.6500179e+07, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00]])

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state= 42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
## Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

number_input_features = len( X_train_scaled[0])
hidden_nodes_layer1=7
hidden_nodes_layer2=14
hidden_nodes_layer3=21
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 7)                 3227
# _________________________________________________________________
# dense_13 (Dense)             (None, 14)                112
# _________________________________________________________________
# dense_14 (Dense)             (None, 21)                315
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 22
# =================================================================
# Total params: 3,676
# Trainable params: 3,676
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,validation_split=0.15, epochs=100)
# Out:
# Epoch 1/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7374 - val_loss: 0.4552 - val_accuracy: 0.7792
# Epoch 2/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4479 - accuracy: 0.7828 - val_loss: 0.4421 - val_accuracy: 0.7891
# Epoch 3/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4375 - accuracy: 0.7871 - val_loss: 0.4346 - val_accuracy: 0.7922
# Epoch 4/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4327 - accuracy: 0.7905 - val_loss: 0.4357 - val_accuracy: 0.7898
# Epoch 5/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4319 - accuracy: 0.7898 - val_loss: 0.4331 - val_accuracy: 0.7958
# Epoch 6/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4299 - accuracy: 0.7913 - val_loss: 0.4343 - val_accuracy: 0.7976
# Epoch 7/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4286 - accuracy: 0.7923 - val_loss: 0.4395 - val_accuracy: 0.7906
# Epoch 8/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4279 - accuracy: 0.7936 - val_loss: 0.4365 - val_accuracy: 0.7976
# Epoch 9/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4268 - accuracy: 0.7942 - val_loss: 0.4374 - val_accuracy: 0.7940
# Epoch 10/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4259 - accuracy: 0.7947 - val_loss: 0.4387 - val_accuracy: 0.7955
# Epoch 11/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4252 - accuracy: 0.7941 - val_loss: 0.4382 - val_accuracy: 0.7961
# Epoch 12/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4247 - accuracy: 0.7949 - val_loss: 0.4395 - val_accuracy: 0.8005
# Epoch 13/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4227 - accuracy: 0.7957 - val_loss: 0.4400 - val_accuracy: 0.7999
# Epoch 14/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4227 - accuracy: 0.7957 - val_loss: 0.4388 - val_accuracy: 0.7950
# Epoch 15/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4222 - accuracy: 0.7974 - val_loss: 0.4389 - val_accuracy: 0.7997
# Epoch 16/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4219 - accuracy: 0.7983 - val_loss: 0.4406 - val_accuracy: 0.7979
# Epoch 17/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4213 - accuracy: 0.7983 - val_loss: 0.4362 - val_accuracy: 0.8018
# Epoch 18/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4213 - accuracy: 0.7984 - val_loss: 0.4378 - val_accuracy: 0.8005
# Epoch 19/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4206 - accuracy: 0.7979 - val_loss: 0.4373 - val_accuracy: 0.8025
# Epoch 20/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4199 - accuracy: 0.8002 - val_loss: 0.4380 - val_accuracy: 0.8005
# Epoch 21/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4200 - accuracy: 0.7992 - val_loss: 0.4394 - val_accuracy: 0.8007
# Epoch 22/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4194 - accuracy: 0.7989 - val_loss: 0.4391 - val_accuracy: 0.8010
# Epoch 23/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4197 - accuracy: 0.7993 - val_loss: 0.4391 - val_accuracy: 0.8023
# Epoch 24/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4193 - accuracy: 0.8000 - val_loss: 0.4399 - val_accuracy: 0.8005
# Epoch 25/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4192 - accuracy: 0.7995 - val_loss: 0.4383 - val_accuracy: 0.8002
# Epoch 26/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4189 - accuracy: 0.8007 - val_loss: 0.4402 - val_accuracy: 0.7955
# Epoch 27/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4188 - accuracy: 0.8001 - val_loss: 0.4401 - val_accuracy: 0.8041
# Epoch 28/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4182 - accuracy: 0.7999 - val_loss: 0.4422 - val_accuracy: 0.8020
# Epoch 29/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4181 - accuracy: 0.8004 - val_loss: 0.4404 - val_accuracy: 0.8010
# Epoch 30/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4183 - accuracy: 0.7999 - val_loss: 0.4417 - val_accuracy: 0.7979
# Epoch 31/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4178 - accuracy: 0.7995 - val_loss: 0.4396 - val_accuracy: 0.8018
# Epoch 32/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4177 - accuracy: 0.8002 - val_loss: 0.4398 - val_accuracy: 0.8007
# Epoch 33/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4175 - accuracy: 0.8003 - val_loss: 0.4422 - val_accuracy: 0.8018
# Epoch 34/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4177 - accuracy: 0.7997 - val_loss: 0.4392 - val_accuracy: 0.8044
# Epoch 35/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4175 - accuracy: 0.8000 - val_loss: 0.4407 - val_accuracy: 0.8005
# Epoch 36/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4174 - accuracy: 0.7997 - val_loss: 0.4413 - val_accuracy: 0.8031
# Epoch 37/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4170 - accuracy: 0.8005 - val_loss: 0.4395 - val_accuracy: 0.8018
# Epoch 38/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4165 - accuracy: 0.8005 - val_loss: 0.4415 - val_accuracy: 0.8028
# Epoch 39/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4167 - accuracy: 0.8001 - val_loss: 0.4431 - val_accuracy: 0.8010
# Epoch 40/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4162 - accuracy: 0.7995 - val_loss: 0.4420 - val_accuracy: 0.7994
# Epoch 41/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4166 - accuracy: 0.8007 - val_loss: 0.4393 - val_accuracy: 0.8041
# Epoch 42/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4160 - accuracy: 0.8018 - val_loss: 0.4410 - val_accuracy: 0.8010
# Epoch 43/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4157 - accuracy: 0.8014 - val_loss: 0.4437 - val_accuracy: 0.8025
# Epoch 44/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4162 - accuracy: 0.8005 - val_loss: 0.4418 - val_accuracy: 0.8028
# Epoch 45/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4165 - accuracy: 0.8004 - val_loss: 0.4421 - val_accuracy: 0.8033
# Epoch 46/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4159 - accuracy: 0.8016 - val_loss: 0.4414 - val_accuracy: 0.8025
# Epoch 47/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4157 - accuracy: 0.8006 - val_loss: 0.4410 - val_accuracy: 0.8023
# Epoch 48/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4157 - accuracy: 0.8011 - val_loss: 0.4413 - val_accuracy: 0.7984
# Epoch 49/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4154 - accuracy: 0.8000 - val_loss: 0.4416 - val_accuracy: 0.8028
# Epoch 50/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4152 - accuracy: 0.8013 - val_loss: 0.4457 - val_accuracy: 0.7984
# Epoch 51/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4150 - accuracy: 0.8020 - val_loss: 0.4429 - val_accuracy: 0.8005
# Epoch 52/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4148 - accuracy: 0.8018 - val_loss: 0.4404 - val_accuracy: 0.8020
# Epoch 53/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4147 - accuracy: 0.8013 - val_loss: 0.4437 - val_accuracy: 0.8023
# Epoch 54/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4147 - accuracy: 0.8021 - val_loss: 0.4433 - val_accuracy: 0.8018
# Epoch 55/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4146 - accuracy: 0.8021 - val_loss: 0.4429 - val_accuracy: 0.8044
# Epoch 56/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4144 - accuracy: 0.8013 - val_loss: 0.4433 - val_accuracy: 0.8007
# Epoch 57/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4141 - accuracy: 0.8018 - val_loss: 0.4431 - val_accuracy: 0.8007
# Epoch 58/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4137 - accuracy: 0.8017 - val_loss: 0.4447 - val_accuracy: 0.8023
# Epoch 59/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4144 - accuracy: 0.8016 - val_loss: 0.4432 - val_accuracy: 0.8018
# Epoch 60/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4146 - accuracy: 0.8012 - val_loss: 0.4441 - val_accuracy: 0.7989
# Epoch 61/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4143 - accuracy: 0.8017 - val_loss: 0.4422 - val_accuracy: 0.8018
# Epoch 62/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4140 - accuracy: 0.8015 - val_loss: 0.4439 - val_accuracy: 0.8028
# Epoch 63/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4140 - accuracy: 0.8027 - val_loss: 0.4444 - val_accuracy: 0.8031
# Epoch 64/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4138 - accuracy: 0.8026 - val_loss: 0.4451 - val_accuracy: 0.8015
# Epoch 65/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4135 - accuracy: 0.8031 - val_loss: 0.4445 - val_accuracy: 0.7999
# Epoch 66/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4138 - accuracy: 0.8023 - val_loss: 0.4454 - val_accuracy: 0.8002
# Epoch 67/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4136 - accuracy: 0.8036 - val_loss: 0.4442 - val_accuracy: 0.8038
# Epoch 68/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4133 - accuracy: 0.8020 - val_loss: 0.4446 - val_accuracy: 0.8023
# Epoch 69/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4125 - accuracy: 0.8026 - val_loss: 0.4468 - val_accuracy: 0.7987
# Epoch 70/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4134 - accuracy: 0.8025 - val_loss: 0.4450 - val_accuracy: 0.8005
# Epoch 71/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4129 - accuracy: 0.8031 - val_loss: 0.4444 - val_accuracy: 0.8031
# Epoch 72/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4125 - accuracy: 0.8025 - val_loss: 0.4458 - val_accuracy: 0.7997
# Epoch 73/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4126 - accuracy: 0.8033 - val_loss: 0.4451 - val_accuracy: 0.8007
# Epoch 74/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4126 - accuracy: 0.8028 - val_loss: 0.4458 - val_accuracy: 0.8015
# Epoch 75/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4127 - accuracy: 0.8035 - val_loss: 0.4434 - val_accuracy: 0.8015
# Epoch 76/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4120 - accuracy: 0.8033 - val_loss: 0.4515 - val_accuracy: 0.8002
# Epoch 77/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4127 - accuracy: 0.8026 - val_loss: 0.4455 - val_accuracy: 0.8041
# Epoch 78/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4117 - accuracy: 0.8032 - val_loss: 0.4483 - val_accuracy: 0.8012
# Epoch 79/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4122 - accuracy: 0.8022 - val_loss: 0.4457 - val_accuracy: 0.8018
# Epoch 80/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4122 - accuracy: 0.8032 - val_loss: 0.4460 - val_accuracy: 0.8020
# Epoch 81/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4118 - accuracy: 0.8037 - val_loss: 0.4427 - val_accuracy: 0.8044
# Epoch 82/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4122 - accuracy: 0.8043 - val_loss: 0.4436 - val_accuracy: 0.8025
# Epoch 83/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4112 - accuracy: 0.8040 - val_loss: 0.4475 - val_accuracy: 0.8018
# Epoch 84/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4119 - accuracy: 0.8040 - val_loss: 0.4478 - val_accuracy: 0.8031
# Epoch 85/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4118 - accuracy: 0.8021 - val_loss: 0.4491 - val_accuracy: 0.8010
# Epoch 86/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4110 - accuracy: 0.8044 - val_loss: 0.4492 - val_accuracy: 0.7976
# Epoch 87/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4111 - accuracy: 0.8039 - val_loss: 0.4453 - val_accuracy: 0.7976
# Epoch 88/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4109 - accuracy: 0.8049 - val_loss: 0.4481 - val_accuracy: 0.8002
# Epoch 89/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4107 - accuracy: 0.8044 - val_loss: 0.4473 - val_accuracy: 0.8010
# Epoch 90/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4110 - accuracy: 0.8040 - val_loss: 0.4492 - val_accuracy: 0.8020
# Epoch 91/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4108 - accuracy: 0.8039 - val_loss: 0.4486 - val_accuracy: 0.7984
# Epoch 92/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4105 - accuracy: 0.8042 - val_loss: 0.4486 - val_accuracy: 0.8002
# Epoch 93/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4107 - accuracy: 0.8040 - val_loss: 0.4449 - val_accuracy: 0.7989
# Epoch 94/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4102 - accuracy: 0.8031 - val_loss: 0.4479 - val_accuracy: 0.8010
# Epoch 95/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4106 - accuracy: 0.8044 - val_loss: 0.4460 - val_accuracy: 0.8012
# Epoch 96/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4103 - accuracy: 0.8042 - val_loss: 0.4450 - val_accuracy: 0.7992
# Epoch 97/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4102 - accuracy: 0.8031 - val_loss: 0.4454 - val_accuracy: 0.8025
# Epoch 98/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4102 - accuracy: 0.8038 - val_loss: 0.4473 - val_accuracy: 0.8002
# Epoch 99/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4103 - accuracy: 0.8037 - val_loss: 0.4458 - val_accuracy: 0.8007
# Epoch 100/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4099 - accuracy: 0.8046 - val_loss: 0.4475 - val_accuracy: 0.8012

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.4658 - accuracy: 0.7836
# Loss: 0.46582144498825073, Accuracy: 0.7835568785667419

# %%
# Export our model to HDF5 file
from google.colab import files

nn.save('/content/AlphabetSoupCharity_Optimization.h5')
files.download('/content/AlphabetSoupCharity_Optimization.h5')
